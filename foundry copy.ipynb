# %%
import numpy as np 
import pandas as pd 
import plotly.express as px

# %%
path = 'data/raw/air_quality/co_1980_'

states = ['alabama', 'alaska', 'arizona', 'california', 'colorado', 'connecticut', 
          'delaware', 'district_of_columbia', 'florida', 'georgia', 'hawaii', 'idaho', 
          'illinois', 'indiana', 'iowa', 'kansas', 'kentucky', 'maine', 'maryland', 
          'massachusetts', 'michigan', 'minnesota', 'mississippi', 'missouri', 'montana', 
          'nebraska', 'nevada', 'new_hampshire', 'new_jersey', 'new_mexico', 'new_york', 
          'north_carolina', 'ohio', 'oklahoma', 'oregon', 'pennsylvania', 'rhode_island', 
          'south_carolina', 'tennessee', 'texas', 'utah', 'vermont', 'virginia', 
          'washington', 'west_virginia', 'wisconsin'] 

cols = ['date', 'aqs_site_id', 'daily_max_8_hour_co_concentration', 
        'cbsa_name', 'state', 'county']

# %%
dfs = [pd.read_csv(f'{path}{state}.csv', usecols=cols, parse_dates=['date']) for state in states] 
df = pd.concat(dfs)
df.head(3)
# Out:
#         date  aqs_site_id  daily_max_8_hour_co_concentration  \
# 0 1980-01-01     10730012                                4.5
# 1 1980-01-02     10730012                                9.5
# 2 1980-01-03     10730012                                8.6
#
#                cbsa_name    state     county
# 0  Birmingham-Hoover, AL  Alabama  Jefferson
# 1  Birmingham-Hoover, AL  Alabama  Jefferson
# 2  Birmingham-Hoover, AL  Alabama  Jefferson

# %%
df['site'] = df['cbsa_name'] + ' - ' + df['aqs_site_id'].astype(str) 

df.drop(columns=['aqs_site_id', 'cbsa_name'], inplace=True)
df.rename(columns={'daily_max_8_hour_co_concentration':'Max CO', 'date':'Date', 
                   'state':'State', 'county':'County', 'site':'Site'}, inplace=True)

df.sort_values(['State', 'County', 'Site', 'Date'], inplace=True)

df.head()
# Out:
#         Date  Max CO    State     County                              Site
# 0 1980-01-01     4.5  Alabama  Jefferson  Birmingham-Hoover, AL - 10730012
# 1 1980-01-02     9.5  Alabama  Jefferson  Birmingham-Hoover, AL - 10730012
# 2 1980-01-03     8.6  Alabama  Jefferson  Birmingham-Hoover, AL - 10730012
# 3 1980-01-04     3.6  Alabama  Jefferson  Birmingham-Hoover, AL - 10730012
# 4 1980-01-05     2.2  Alabama  Jefferson  Birmingham-Hoover, AL - 10730012

# %%
dfi = df[df['State']=='Ohio'] 
dfi['County'].unique()
# Out:
# array(['Butler', 'Cuyahoga', 'Franklin', 'Hamilton', 'Jefferson', 'Lake',
#        'Lucas', 'Mahoning', 'Montgomery', 'Stark', 'Summit'], dtype=object)

# %%
dfi = df[(df['State']=='Ohio') & (df['County']=='Franklin')] 
px.line(dfi, x='Date', y='Max CO', color='Site')

# %%
df_name = 'asdfasdfasdf' 

df.to_pickle(f'data/pkl/{df_name}.pkl')
